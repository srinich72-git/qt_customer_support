# %%
from langchain_core.language_models.chat_models import BaseChatModel
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

def run_chat(llm: BaseChatModel):
    response = llm.invoke([
        HumanMessage(content="Explain REST API in one sentence")
    ])
    return response.content

# create actual model (implementation of BaseChatModel)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# pass it where BaseChatModel is expected
output = run_chat(llm)

print(output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from langchain_core.language_models.chat_models import BaseChatModel
# ----> 2 from langchain_openai import ChatOpenAI
#       3 from langchain_core.messages import HumanMessage
#       4
#       5 def run_chat(llm: BaseChatModel):
#
# ModuleNotFoundError: No module named 'langchain_openai'
